# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
#tips=pd.read_csv('C:/Users/Administrator/Desktop/Data visualization/datasets/adult.csv')
tips=sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
plt.show()

# %%
sns.countplot(x='sex',data=tips)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.boxplot(x='day',y='tip',data=tips)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',hue='sex',data=tips)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',hue='sex',data=tips)
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker',palette='Set1')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker',palette='Set1',split=True)
plt.show()

# %%
#can tell the skewnness

sns.violinplot(y='day',x='total_bill',data=tips,hue='smoker',palette='Set1',split=True)
plt.show()

# %%
sns.violinplot(y='day',x='tip',data=tips,hue='smoker',palette='Set1',split=True)
plt.show()

# %%
sns.stripplot(x='day',y='tip',data=tips,split=True)
plt.show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\seaborn\categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='smoker',jitter=True)
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
#analysis of adult dataset

# %%
ad=pd.read_csv('C:/Users/Administrator/Desktop/Data visualization/datasets/adult.csv')
ad100=ad.head(100)
ad
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       25           Private  226802          11th                7
# 1       38           Private   89814       HS-grad                9
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 4       18                 ?  103497  Some-college               10
# 5       34           Private  198693          10th                6
# 6       29                 ?  227026       HS-grad                9
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# 8       24           Private  369667  Some-college               10
# 9       55           Private  104996       7th-8th                4
# 10      65           Private  184454       HS-grad                9
# 11      36       Federal-gov  212465     Bachelors               13
# 12      26           Private   82091       HS-grad                9
# ...

# %%
perc=ad.groupby(['workclass','gender']).size()
perc=pd.DataFrame(perc)
perc=perc.reset_index()
perc=perc.rename(columns={0:'count'})
perc

#perc_f=perc.query('gender=="Female"')
#perc_f=perc_f.reset_index()
#perc_f=perc_f.rename(columns={0:'count'})
#print(perc_f)

#perc_m=perc.query('gender=="Male"')
#perc_m=perc_m.reset_index()
#perc_m=perc_m.rename(columns={0:'count'})
#print(perc_m)

#fig=plt.figure(figsize=(12,7))
#plt.pie(perc['count'],labels=perc['workclass'],startangle=90,autopct='%1.1f%%',
       #explode=(.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2,.2))
#plt.axis('equal')
#plt.legend(perc['gender'])
#plt.show()

#plt.bar(perc['workclass'],perc['count'],edgecolor='black')
#plt.legend(perc['gender'])
#plt.xticks(rotation=45)
#plt.yticks(np.arange(0,25000,1000))
#plt.show()

plt.figure(figsize=(20,7))
sns.countplot(x='workclass',data=ad,hue='gender')
plt.show()

# %%
help(sns.countplot)
# Out:
# Help on function countplot in module seaborn.categorical:
#
# countplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)
#     Show the counts of observations in each categorical bin using bars.
#
#     A count plot can be thought of as a histogram across a categorical, instead
#     of quantitative, variable. The basic API and options are identical to those
#     for :func:`barplot`, so you can compare counts across nested variables.
#
#     Input data can be passed in a variety of formats, including:
#
#     - Vectors of data represented as lists, numpy arrays, or pandas Series
#       objects passed directly to the ``x``, ``y``, and/or ``hue`` parameters.
#     - A "long-form" DataFrame, in which case the ``x``, ``y``, and ``hue``
#       variables will determine how the data are plotted.
#     - A "wide-form" DataFrame, such that each numeric column will be plotted.
# ...

# %%
perc=ad.groupby(['workclass','gender']).size()
perc=pd.DataFrame(perc)
perc=perc.reset_index()
perc=perc.rename(columns={0:'count'})
perc

fig=plt.figure(figsize=(20,10))
plt.pie(perc['count'],labels=perc['gender'],startangle=90,autopct='%1.1f%%',
       explode=(.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25,.25),rotatelabels=90,
       radius=1,pctdistance=0.9)
plt.axis('equal')
plt.legend(perc['workclass'])
plt.show()

import matplotlib as mpl
mpl.rcParams['font.size']=15.0
